# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("2016_raw_08062019.xlsx")

# %%
df.head()
# Out:
#   O_Country  O_City                           O_Terminal D_Country    D_City  \
# 0    Poland  Gdansk  Gdansk Deepwater Container Terminal    Poland    Poznan
# 1    Poland  Gdansk  Gdansk Deepwater Container Terminal    Poland  Radomsko
# 2    Poland  Gdynia            Baltic Container Terminal    Poland    Warsaw
# 3    Poland  Gdynia            Baltic Container Terminal    Poland    Poznan
# 4    Poland  Gdynia            Baltic Container Terminal    Poland  Radomsko
#
#                                     D_Terminal Carrier    ID  \
# 0  Terminal Kontenerowy Loconi Intermodal S.A.  Loconi  8507
# 1  Terminal Kontenerowy Loconi Intermodal S.A.  Loconi  8508
# 2                       Terminal not specified  Loconi  8509
# 3  Terminal Kontenerowy Loconi Intermodal S.A.  Loconi  8510
# 4  Terminal Kontenerowy Loconi Intermodal S.A.  Loconi  8511
#
#   Transportation mode  Monday  ...  Thursday  Friday  Saturday  Sunday  \
# 0                Rail       0  ...         0       0         1       0
# 1                Rail       0  ...         0       1         0       0
# 2                Rail       1  ...         1       0         0       0
# 3                Rail       1  ...         1       0         0       0
# 4                Rail       1  ...         1       0         0       0
#
#    Number of departures per week  Transport time (days)  O_City_Longitude  \
# 0                              2                      1         18.628222
# 1                              2                      1         18.628222
# 2                              2                      1         18.462650
# 3                              2                      1         18.462650
# 4                              2                      1         18.462650
#
#    O_City_Latitude  D_City_Longitude  D_City_Latitude
# 0        54.361437         16.919752        52.400652
# 1        54.361437         19.444700        51.067793
# 2        54.503663         21.006726        52.231924
# 3        54.503663         16.919752        52.400652
# 4        54.503663         19.444700        51.067793
#
# [5 rows x 22 columns]

# %%
df.iloc[:,6:].head()
# Out:
#   Carrier    ID Transportation mode  Monday  Tuesday  Wednesday  Thursday  \
# 0  Loconi  8507                Rail       0        1          0         0
# 1  Loconi  8508                Rail       0        1          0         0
# 2  Loconi  8509                Rail       1        0          0         1
# 3  Loconi  8510                Rail       1        0          0         1
# 4  Loconi  8511                Rail       1        0          0         1
#
#    Friday  Saturday  Sunday  Number of departures per week  \
# 0       0         1       0                              2
# 1       1         0       0                              2
# 2       0         0       0                              2
# 3       0         0       0                              2
# 4       0         0       0                              2
#
#    Transport time (days)  O_City_Longitude  O_City_Latitude  D_City_Longitude  \
# 0                      1         18.628222        54.361437         16.919752
# 1                      1         18.628222        54.361437         19.444700
# 2                      1         18.462650        54.503663         21.006726
# 3                      1         18.462650        54.503663         16.919752
# 4                      1         18.462650        54.503663         19.444700
#
#    D_City_Latitude
# 0        52.400652
# 1        51.067793
# 2        52.231924
# 3        52.400652
# 4        51.067793

# %%
# Algorithm terminal layout 2 for saving the latitude and longitude value to be called when making dataframe
dict_loc_origin = {df['O_City'][x]:(df['O_City_Latitude'][x], df['O_City_Longitude'][x]) for x in range(len(df))}
dict_loc_destination = {df['D_City'][x]:(df['D_City_Latitude'][x], df['D_City_Longitude'][x]) for x in range(len(df))}

# %%
# Sum untuk quantify jumlah departure per week dan transport time days
# Count untuk menghitung jumlah service
df_group = df.groupby(by=["O_City","D_City","Transportation mode","Carrier"]).count()

# %%
df_group.head()
# Out:
#                                                  O_Country  O_Terminal  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM          1           1
#         Copenhagen  Sea                 CMA-CGM          1           1
#         Hamburg     Sea                 CMA-CGM          2           2
#         Helsingborg Sea                 CMA-CGM          1           1
#         Kiel        Sea                 CMA-CGM          1           1
#
#                                                  D_Country  D_Terminal  ID  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM          1           1   1
#         Copenhagen  Sea                 CMA-CGM          1           1   1
#         Hamburg     Sea                 CMA-CGM          2           2   2
#         Helsingborg Sea                 CMA-CGM          1           1   1
#         Kiel        Sea                 CMA-CGM          1           1   1
#
#                                                  Monday  Tuesday  Wednesday  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM       1        1          1
#         Copenhagen  Sea                 CMA-CGM       1        1          1
#         Hamburg     Sea                 CMA-CGM       2        2          2
#         Helsingborg Sea                 CMA-CGM       1        1          1
#         Kiel        Sea                 CMA-CGM       1        1          1
#
#                                                  Thursday  Friday  Saturday  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM         1       1         1
#         Copenhagen  Sea                 CMA-CGM         1       1         1
#         Hamburg     Sea                 CMA-CGM         2       2         2
#         Helsingborg Sea                 CMA-CGM         1       1         1
#         Kiel        Sea                 CMA-CGM         1       1         1
#
#                                                  Sunday  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM       1
#         Copenhagen  Sea                 CMA-CGM       1
#         Hamburg     Sea                 CMA-CGM       2
#         Helsingborg Sea                 CMA-CGM       1
#         Kiel        Sea                 CMA-CGM       1
#
#                                                  Number of departures per week  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM                              1
#         Copenhagen  Sea                 CMA-CGM                              1
#         Hamburg     Sea                 CMA-CGM                              2
#         Helsingborg Sea                 CMA-CGM                              1
#         Kiel        Sea                 CMA-CGM                              1
#
#                                                  Transport time (days)  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM                      1
#         Copenhagen  Sea                 CMA-CGM                      1
#         Hamburg     Sea                 CMA-CGM                      2
#         Helsingborg Sea                 CMA-CGM                      1
#         Kiel        Sea                 CMA-CGM                      1
#
#                                                  O_City_Longitude  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM                 0
#         Copenhagen  Sea                 CMA-CGM                 0
#         Hamburg     Sea                 CMA-CGM                 0
#         Helsingborg Sea                 CMA-CGM                 0
#         Kiel        Sea                 CMA-CGM                 0
#
#                                                  O_City_Latitude  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM                0
#         Copenhagen  Sea                 CMA-CGM                0
#         Hamburg     Sea                 CMA-CGM                0
#         Helsingborg Sea                 CMA-CGM                0
#         Kiel        Sea                 CMA-CGM                0
#
#                                                  D_City_Longitude  \
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM                 0
#         Copenhagen  Sea                 CMA-CGM                 1
#         Hamburg     Sea                 CMA-CGM                 2
#         Helsingborg Sea                 CMA-CGM                 1
#         Kiel        Sea                 CMA-CGM                 1
#
#                                                  D_City_Latitude
# O_City  D_City      Transportation mode Carrier
# Aalborg Aarhus      Sea                 CMA-CGM                0
#         Copenhagen  Sea                 CMA-CGM                1
#         Hamburg     Sea                 CMA-CGM                2
#         Helsingborg Sea                 CMA-CGM                1
#         Kiel        Sea                 CMA-CGM                1

# %%
# Make another dataframe to group only 3 index
df_group_3index = df.groupby(by=["O_City","D_City","Transportation mode"]).count()

# %%
three_level_index = list(df_group_3index.index)

# %%
three_level_index[:5]
# Out:
# [('Aalborg', 'Aarhus', 'Sea'),
#  ('Aalborg', 'Copenhagen', 'Sea'),
#  ('Aalborg', 'Hamburg', 'Sea'),
#  ('Aalborg', 'Helsingborg', 'Sea'),
#  ('Aalborg', 'Kiel', 'Sea')]

# %%
# testing
df_group.loc[three_level_index[0],:]
# Out:
#          O_Country  O_Terminal  D_Country  D_Terminal  ID  Monday  Tuesday  \
# Carrier
# CMA-CGM          1           1          1           1   1       1        1
#
#          Wednesday  Thursday  Friday  Saturday  Sunday  \
# Carrier
# CMA-CGM          1         1       1         1       1
#
#          Number of departures per week  Transport time (days)  \
# Carrier
# CMA-CGM                              1                      1
#
#          O_City_Longitude  O_City_Latitude  D_City_Longitude  D_City_Latitude
# Carrier
# CMA-CGM                 0                0                 0                0

# %%
dict_carrier_number = dict()
for i, j in enumerate(three_level_index):
    dict_carrier_number[j] = len(df_group.loc[three_level_index[i],:])

# %%
dict_carrier_number[('Rotterdam','Antwerp','Sea')]
# Out:
# 9

# %%
# Make new dataframe to contain the result
df_carrier_number = pd.DataFrame(columns=['O_City','D_City','Modality','No_carrier','departure_per_week','avg_travel_time','link_weight','o_city_lat','o_city_lon','d_city_lat','d_city_lon'], index=range(len(three_level_index)))

# %%
df_carrier_number.head()
# Out:
#   O_City D_City Modality No_carrier departure_per_week avg_travel_time  \
# 0    NaN    NaN      NaN        NaN                NaN             NaN
# 1    NaN    NaN      NaN        NaN                NaN             NaN
# 2    NaN    NaN      NaN        NaN                NaN             NaN
# 3    NaN    NaN      NaN        NaN                NaN             NaN
# 4    NaN    NaN      NaN        NaN                NaN             NaN
#
#   link_weight o_city_lat o_city_lon d_city_lat d_city_lon
# 0         NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN

# %%
for i, j in enumerate(three_level_index):
    df_carrier_number['O_City'].iloc[i] = three_level_index[i][0]
    df_carrier_number['D_City'].iloc[i] = three_level_index[i][1]
    df_carrier_number['Modality'].iloc[i] = three_level_index[i][2]
    df_carrier_number['No_carrier'].iloc[i] = dict_carrier_number[j]

# %%
df_carrier_number[df_carrier_number['O_City'] == 'Rotterdam'].head()
# Out:
#          O_City        D_City         Modality  No_carrier departure_per_week  \
# 4251  Rotterdam        Aarhus              Sea           6                NaN
# 4252  Rotterdam        Agadir              Sea           3                NaN
# 4253  Rotterdam  Alblasserdam  Inland shipping           1                NaN
# 4254  Rotterdam       Alesund              Sea           2                NaN
# 4255  Rotterdam    Alexandria              Sea           5                NaN
#
#      avg_travel_time link_weight o_city_lat o_city_lon d_city_lat d_city_lon
# 4251             NaN         NaN        NaN        NaN        NaN        NaN
# 4252             NaN         NaN        NaN        NaN        NaN        NaN
# 4253             NaN         NaN        NaN        NaN        NaN        NaN
# 4254             NaN         NaN        NaN        NaN        NaN        NaN
# 4255             NaN         NaN        NaN        NaN        NaN        NaN

# %%
# Fill the coordinate
for i in range(len(df_carrier_number)):
    df_carrier_number['o_city_lat'].iloc[i] = dict_loc_origin[df_carrier_number['O_City'].iloc[i]][0]
    df_carrier_number['o_city_lon'].iloc[i] = dict_loc_origin[df_carrier_number['O_City'].iloc[i]][1]
    df_carrier_number['d_city_lat'].iloc[i] = dict_loc_destination[df_carrier_number['D_City'].iloc[i]][0]
    df_carrier_number['d_city_lon'].iloc[i] = dict_loc_destination[df_carrier_number['D_City'].iloc[i]][1]
# Out:
# /Users/andreas.yunus/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# Combine information about number of frequency to the dataframe

# %%
df_freq = df.groupby(by=["O_City","D_City","Transportation mode"]).sum()

# %%
df_time = df.groupby(by=["O_City","D_City","Transportation mode"]).mean()

# %%
df_freq.loc[('Rotterdam','Antwerp','Sea'),:]['Number of departures per week']
# Out:
# 84.0

# %%
df_time.loc[('Rotterdam','Antwerp','Sea'),:]['Transport time (days)']
# Out:
# 5.633333333333334

# %%
for i, j in enumerate(three_level_index):
    df_carrier_number['departure_per_week'].iloc[i] = df_freq.loc[j]["Number of departures per week"]
    df_carrier_number['avg_travel_time'].iloc[i] = df_time.loc[j]["Transport time (days)"]
# Out:
# /Users/andreas.yunus/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_carrier_number[df_carrier_number['O_City'] == 'Rotterdam'].head()
# Out:
#          O_City        D_City         Modality  No_carrier  \
# 4251  Rotterdam        Aarhus              Sea           6
# 4252  Rotterdam        Agadir              Sea           3
# 4253  Rotterdam  Alblasserdam  Inland shipping           1
# 4254  Rotterdam       Alesund              Sea           2
# 4255  Rotterdam    Alexandria              Sea           5
#
#       departure_per_week avg_travel_time link_weight o_city_lat o_city_lon  \
# 4251                  13         3.69231         NaN    51.9278    4.48862
# 4252                   8         11.4286         NaN    51.9278    4.48862
# 4253                  12               1         NaN    51.9278    4.48862
# 4254                   4             4.5         NaN    51.9278    4.48862
# 4255                  11            16.5         NaN    51.9278    4.48862
#
#      d_city_lat d_city_lon
# 4251        NaN        NaN
# 4252        NaN        NaN
# 4253      51.86     4.6662
# 4254        NaN        NaN
# 4255        NaN        NaN

# %%
#for i in range(len(df_carrier_number)):
 #   df_carrier_number['link_weight'][i] = (df_carrier_number['No_carrier'].iloc[i] * df_carrier_number['departure_per_week'].iloc[i])/df_carrier_number['travel_time'].iloc[i]

# %%
#df_carrier_number.head()

# %%
df_carrier_number['link_weight'] = df_carrier_number['departure_per_week']

# %%
df_carrier_number.to_csv("link_weight_2016.csv",index=False)

# %%
# Modify link weight

# %%
# Modify file centrality by weight
# Modify file weighted link - done
# modify file 12 hubs by weight - done
# PCA - unweighted vs weighted
# PCA - clustering by numbers, by multiplexity, by K-core itself
